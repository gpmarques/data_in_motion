# %% [markdown]
# # Módulo criado para codificar os vídeos em mp4 para os arquivos .tfrecords, que serão utilizados para alimentar e treinar o algoritmo generativo

# %%
import tensorflow as tf
import skvideo.io
import cv2
import os
import numpy as np

# %%
def get_frames(fname):
    """ 
    Função que lê um video em um numpy array de shape:
        (número de frames, altura, comprimento, 3)
    """
    return skvideo.io.vread(fname)

# %%
def _int64_feature(value):
    """ Função que cria uma Feature do tipo int64 a ser inserida em um Example. """
    if not isinstance(value, list):
        value = [value]
    return tf.train.Feature(int64_list=tf.train.Int64List(value=value))

def _bytes_feature(value):
    """ Função que cria uma Feature do tipo Bytes a ser inserida em um Example. """
    return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value]))

# %%
def get_final_size(dim):
    """ Função que retorna a maior potência de 2 menor que uma """
    final_size = 1024
    while dim < final_size:
        final_size /= 2
    return final_size

def crop(image):
    """ Recorta o centro de uma imagem """
    height = image.shape[0]
    width = image.shape[1]
    smaller_dim = height if height < width else width
    if smaller_dim < 128:
        raise ValueError("Smallest dim of frames should be at least greater than 128px")
    final_size = get_final_size(smaller_dim)
    y = int((height - final_size)/2)
    x = int((width - final_size)/2)
    return image[y: height-y, x:width-x]

def resize(img, final_size=(128, 128)):
    return cv2.resize(img, final_size, interpolation=cv2.INTER_LINEAR)

def preprocess(img):
    return resize(crop(img))

# %%
def video_to_tfrecord_example(video_path):
    """ Codifica um mp4 em um Example de tfrecord """
    if not os.path.exists(video_path):
        print("{0} path not found")
        return
    
    frames = [preprocess(frame) for frame in get_frames(video_path)]
    
    encoded_frames = [tf.compat.as_bytes(cv2.imencode(".jpg", frame)[1].tobytes())
                      for frame in frames]
    frames = tf.stack(frames)
    
    features = {}
    features['num_frames']  = _int64_feature(frames.shape[0])
    features['height']      = _int64_feature(frames.shape[1])
    features['width']       = _int64_feature(frames.shape[2])
    
    for i, bytes_frame in enumerate(encoded_frames):
        features['frames/{:04d}'.format(i)] = _bytes_feature(bytes_frame)
        
    tfrecord_example = tf.train.Example(features=tf.train.Features(feature=features))
    
    print("filename: {}, num_frames: {}, height: {}, width: {}".format(
            video_path.split("/")[1], frames.shape[0], frames.shape[1], frames.shape[2]))
    return tfrecord_example

# %%
# tfrec_example = video_to_tfrecord_example(teaser_names[0])
# Out:
# filename: Ilumno Uva Vert Azul_05.mp4, num_frames: 320, height: 128, width: 128

# %%
def write_video_batch_to_tfrecords(video_paths, output_path):
    """ Acessa n videos e os codificae em arquivos .tfrecord """
    with tf.python_io.TFRecordWriter(output_path) as writer:
        for path in video_paths:
            try:
                tfrec_example = video_to_tfrecord_example(path)
                writer.write(tfrec_example.SerializeToString())
            except Exception as e:
                print("video path: {}, exception: {}".format(path, str(e)))

# %%
EXAMPLES_PER_TFRECORD = 20
def get_slice_indexes(ith, num_teasers):
    start_index = ith*EXAMPLES_PER_TFRECORD
    end_index = ith*EXAMPLES_PER_TFRECORD + EXAMPLES_PER_TFRECORD - 1
    if end_index > num_teasers:
        end_index = num_teasers
    return start_index, end_index

def create_tfrecord_fname(i):
    return '_'.join(['teasers', str(i)]) + ".tfrecords"

def teaser_dataset_to_tfrecords():
    """ Codifica o dataset todo para arquivos tfrecords """
    output_dir = '/../../../../newvolume/samples_v4.0'
    if not os.path.exists(output_dir): 
        os.mkdir(output_dir)
        
    teaser_paths = tf.gfile.Glob("teasers/*.mp4")
    num_teasers = len(teaser_paths)
    num_tfrecords = int(np.ceil(num_teasers/EXAMPLES_PER_TFRECORD))
    
    for i in range(num_tfrecords):
        if i == 0:
            batch_paths = teaser_paths[i: EXAMPLES_PER_TFRECORD-1]
        else:
            start, end = get_slice_indexes(i, num_teasers)
            batch_paths = teaser_paths[start: end]
        
        tfrecord_fname = create_tfrecord_fname(i)
        print("writing tfrecord: {}".format(tfrecord_fname))
        output_path = os.path.join(output_dir, tfrecord_fname)
        
        write_video_batch_to_tfrecords(batch_paths, output_path)

# %%
# for i in range(1, 4):
#     print(get_slice_indexes(i, 75))
#     print(create_tfrecord_fname(i))
# Out:
# (20, 39)
# teasers_1.tfrecords
# (40, 59)
# teasers_2.tfrecords
# (60, 75)
# teasers_3.tfrecords

# %%
# teaser_dataset_to_tfrecords()
# Out:
# writing tfrecord: teasers_0.tfrecords
# filename: Ilumno Uva Vert Azul_05.mp4, num_frames: 320, height: 128, width: 128
# filename: v1_180216_Multishow_BBBMelhoresMomentos_BrigaTodoDia.mp4, num_frames: 900, height: 128, width: 128
# filename: Visa_30_180919_Visa l Cross Border l Promocao Mundo Sem Fronteiras_1L.mp4, num_frames: 751, height: 128, width: 128
# filename: bornlogic_15_180126_ilumnouva horizontal verde_04.mp4, num_frames: 320, height: 128, width: 128
# filename: cidadania ja _30_180927_Video Institucional_Home _2C.mp4, num_frames: 900, height: 128, width: 128
# filename: carro aluguel_30_181001_e possivel alugar no cpf_1b.mp4, num_frames: 900, height: 128, width: 128
# filename: Ilumno Uva Hori Verde_05.mp4, num_frames: 320, height: 128, width: 128
# filename: alfa men_30_180517_seu desempenho caiu.mp4, num_frames: 661, height: 128, width: 128
# filename: alfamen_30_180817_dialogo homem x mulher de_2.mp4, num_frames: 719, height: 128, width: 128
# filename: alfamen_30_180416_pode nao ter mais tratamento.mp4, num_frames: 661, height: 128, width: 128
# filename: biz capital_30_180404_youtube_02.mp4, num_frames: 450, height: 128, width: 128
# filename: bornlogic_15_180126_ilumnouva horizontal azul_04a.mp4, num_frames: 320, height: 128, width: 128
# filename: cidadania ja _30_180928_Video resultado do formulario_2a.mp4, num_frames: 900, height: 128, width: 128
# filename: biz capital_30_180424_youtube_07.mp4, num_frames: 450, height: 128, width: 128
# filename: bit.one_30_180518_video 01 - passo a passo _1b.mp4, num_frames: 661, height: 128, width: 128
# filename: universidad de palermo_15_180111_carreras online_03.mp4, num_frames: 450, height: 128, width: 128
# filename: alfa men_30_181002_de onde vem nossos pacientes poa_1c.mp4, num_frames: 900, height: 128, width: 128
# filename: deezer_30_180427_video tim music_4.mp4, num_frames: 900, height: 128, width: 128
# filename: alfa men_30_180518_30_qual a sua velocidade_03.mp4, num_frames: 902, height: 128, width: 128
# writing tfrecord: teasers_1.tfrecords
# filename: alfamen_30_180822_dialogo homem x mulher de_2c.mp4, num_frames: 719, height: 128, width: 128
# filename: facebook_30_181019_Creative for Whatsapp_PT_1c.mp4, num_frames: 900, height: 128, width: 128
# filename: alfamen_30_180816_dialogo homem x mulher ep.mp4, num_frames: 719, height: 128, width: 128
# filename: alfamen_30_180111_ansiedade de performance_4.mp4, num_frames: 661, height: 128, width: 128
# filename: carro aluguel_30_180819_conversao carroaluguel_1b.mp4, num_frames: 1800, height: 128, width: 128
# filename: alfamen_30_180823_dialogo homem x mulher ep casados_2b.mp4, num_frames: 660, height: 128, width: 128
# filename: alfamen_30_180103_homo_1.mp4, num_frames: 750, height: 128, width: 128
# video path: teasers/eventos_15_170411_boteco insta.mp4, exception:
# filename: conquista_15_180419_conquista jardim amaralina segunda fase.mp4, num_frames: 330, height: 128, width: 128
# filename: colgate_30_181023_colgate naturals_1b_1.mp4, num_frames: 661, height: 128, width: 128
# filename: conquista_15_180627_conquista j amaralina - vertical.mp4, num_frames: 450, height: 128, width: 128
# filename: Cyrela_30_181023_Cyrela Design e Detalhes_1a.mp4, num_frames: 901, height: 128, width: 128
# filename: eco challenge_30_171031_eco desafios_02.mp4, num_frames: 661, height: 128, width: 128
# filename: facebook_15_180626_Campanha Prospect Leads-2018_1b.mp4, num_frames: 330, height: 128, width: 128
# filename: googleunlock_30_180723_norte digital_Alto Vento_1c.mp4, num_frames: 661, height: 128, width: 128
# filename: claro_30_170822_claromusica_2a.mp4, num_frames: 660, height: 128, width: 128
# filename: carro aluguel_30_180924_o que e calcao_1b.mp4, num_frames: 1801, height: 128, width: 128
# filename: adlogados_30_180316_precisa de um advogado_01.mp4, num_frames: 901, height: 128, width: 128
# filename: bornlogic_15_180126_ilumnouva horizontal azul_04.mp4, num_frames: 320, height: 128, width: 128
# writing tfrecord: teasers_2.tfrecords
# filename: alfa men_30_180925_de onde vem nossos pacientes poa.mp4, num_frames: 900, height: 128, width: 128
# filename: colgate_30_180420_colgate total 12 saude visivel_04.mp4, num_frames: 450, height: 128, width: 128
# filename: Aragem Rio_60_180831_Festa de 70 anos Mauro de Oliveira_1a.mp4, num_frames: 902, height: 128, width: 128
# filename: digible_30_171207_digible audio_3.mp4, num_frames: 749, height: 128, width: 128
# filename: eventos_15_170412_oktoberfestv_2.mp4, num_frames: 357, height: 128, width: 128
# filename: alfamen_30_180313_desempenho.mp4, num_frames: 661, height: 128, width: 128
# filename: alfamen_30_180614_Video Alfa Men O que fazer quando ele nao quer funcionar_3.mp4, num_frames: 901, height: 128, width: 128
# filename: beer_30_180807_Video Teste clube de assinaturas_1e.mp4, num_frames: 901, height: 128, width: 128
# filename: Niely gold_15_180927_Video Campanha Condicionador Bomba Niely_2b.mp4, num_frames: 450, height: 128, width: 128
# filename: cidadania ja _30_180928_Video Institucional_Home _2D.mp4, num_frames: 900, height: 128, width: 128
# filename: facebook_15_180626_horizon alto da lapa_2b.mp4, num_frames: 450, height: 128, width: 128
# video path: teasers/adlogados_30_170428_adlogados.mp4, exception:
# filename: colgate_30_171114_golgate90anos_03c.mp4, num_frames: 900, height: 128, width: 128
# filename: facebook_30_180211_Creative for Whatsapp_1a.mp4, num_frames: 900, height: 128, width: 128
# filename: conquista_15_171226_conquista amaralina.mp4, num_frames: 451, height: 128, width: 128
# filename: Ilumno Uva Vert Verde_05.mp4, num_frames: 320, height: 128, width: 128
# filename: bit.one_30_180529_Video 01 - Passo a passo _1d.mp4, num_frames: 900, height: 128, width: 128
# filename: alfamen_30_180412_diabetes x disfuncao eretil_2.mp4, num_frames: 661, height: 128, width: 128
# filename: alfa men_30_180517_coverdox 2.mp4, num_frames: 662, height: 128, width: 128
# writing tfrecord: teasers_3.tfrecords
# filename: v1_180220_Multishow_BBBMelhoresMomentos_PegadinhaDoRato_CLARO.mp4, num_frames: 900, height: 128, width: 128
# filename: alfamen_30_180822_dialogo homem x mulher de_2b.mp4, num_frames: 719, height: 128, width: 128
# filename: facebook_15_180626_horizon alto da lapa_2.mp4, num_frames: 450, height: 128, width: 128
# filename: digimax brasil unipar_30_180928_unipar medicina 2019.mp4, num_frames: 900, height: 128, width: 128
# filename: universidad de palermo_30_180926_abogacia_2c.mp4, num_frames: 450, height: 128, width: 128
# filename: alfamen_30_180822_dialogo homem x mulher de casados_2.mp4, num_frames: 719, height: 128, width: 128
# filename: facebook_15_180529_RMA Comunicacao_Campanha PR SCOPE_1c.mp4, num_frames: 450, height: 128, width: 128
# filename: digible_30_171211_digible audio_6.mp4, num_frames: 749, height: 128, width: 128
# filename: Visa_30_180918_Visa l Cross Border l Promocao Mundo Sem Fronteiras_1d.mp4, num_frames: 800, height: 128, width: 128
# filename: universidad de palermo_15_180116_marketing modalidad online_02.mp4, num_frames: 451, height: 128, width: 128
# filename: adlogados_30_170818_adlogados_1.mp4, num_frames: 661, height: 128, width: 128
# video path: teasers/facebook_15_180627_Unboxing Clube Jorge _ Mateus_1e.mp4, exception: No way to determine width or height from video. Need `-s` in `inputdict`. Consult documentation on I/O.
# filename: colgate_30_180419_colgate total 12 saude visivel_02.mp4, num_frames: 450, height: 128, width: 128
# filename: alfamen_30_180822_dialogo homem x mulher de casados_3.mp4, num_frames: 719, height: 128, width: 128
# filename: facebook_15_180406_RMA Comunicacao_Campanha PR SCOPE_1d.mp4, num_frames: 450, height: 128, width: 128
# filename: carro aluguel_30_180825_conversao carroaluguel_1c.mp4, num_frames: 1800, height: 128, width: 128
# filename: cidadania ja _30_180920_Video resultado do formulario_1c.mp4, num_frames: 900, height: 128, width: 128
# filename: alfamen_30_180615_Video Alfa Men O que fazer quando ele nao quer funcionar_2.mp4, num_frames: 901, height: 128, width: 128
# filename: facebook_15_180529_RMA Comunicacao_Campanha PR SCOPE_1b.mp4, num_frames: 450, height: 128, width: 128
# writing tfrecord: teasers_4.tfrecords
# filename: Ilumno Uva Vert Verde_03.mp4, num_frames: 330, height: 128, width: 128
# filename: arcor_30_180731_Big Big Campanha_1d.mp4, num_frames: 661, height: 128, width: 128
# filename: facebook_15_180612_araujo_1.mp4, num_frames: 330, height: 128, width: 128
# filename: alfamen_30_180712_video quanto tempo deve durar uma relacao.mp4, num_frames: 720, height: 128, width: 128
# filename: conquista_15_180705_conquista j amaralina - horizontal_1b.mp4, num_frames: 330, height: 128, width: 128
# filename: biz capital_30_180420_youtube_06.mp4, num_frames: 450, height: 128, width: 128
# filename: cidadania ja _30_181009_Video resultado do formulario_2b.mp4, num_frames: 900, height: 128, width: 128
# filename: Visa_30_180918_Visa l Cross Border l Promocao Mundo Sem Fronteiras_1c.mp4, num_frames: 800, height: 128, width: 128
# filename: beer_30_180801_Video Teste  - Clube de Assinaturas_1b.mp4, num_frames: 901, height: 128, width: 128
# filename: cidadania ja _30_181016_video de inauguracao da loja niteroi_1b.mp4, num_frames: 360, height: 128, width: 128
# filename: gyramais_30_180719_Como Funciona_1g.mp4, num_frames: 900, height: 128, width: 128
# filename: alfamen_30_180615_como esta o seu desempenho debaixo dos lencois_2.mp4, num_frames: 900, height: 128, width: 128
# filename: b ferraz_30_171219_compartilhar vertical.mp4, num_frames: 451, height: 128, width: 128
# filename: alfa men_30_181001_de onde vem nossos pacientes minas_1b.mp4, num_frames: 900, height: 128, width: 128
# filename: Aragem Rio_60_180831_Festa de 70 anos Mauro de Oliveira_1b.mp4, num_frames: 902, height: 128, width: 128
# filename: carro aluguel_30_180925_e seguro alugar.mp4, num_frames: 900, height: 128, width: 128
# filename: carro aluguel_30_181001_e possivel alugar no cpf_1a.mp4, num_frames: 900, height: 128, width: 128
# filename: carroaluguel.com_30_181019_o que e km livre e controlado__1a.mp4, num_frames: 661, height: 128, width: 128
# filename: colgate_15_181025_promocao_tandy_1.mp4, num_frames: 330, height: 128, width: 128
# writing tfrecord: teasers_5.tfrecords
# filename: beer_30_180820_eisenbahn_1e.mp4, num_frames: 450, height: 128, width: 128
# filename: colgate_15_181022_colgate naturals_1.mp4, num_frames: 330, height: 128, width: 128
# filename: Visa_30_180918_Visa l Cross Border l Promocao Mundo Sem Fronteiras_1g.mp4, num_frames: 751, height: 128, width: 128
# filename: colgate_30_171113_golgate90anos_01.mp4, num_frames: 450, height: 128, width: 128
# filename: facebook_30_181017_Creative for Whatsapp_Espanhol.mp4, num_frames: 900, height: 128, width: 128
# video path: teasers/eventos_15_170412_white rooftop.mp4, exception:
# filename: colgate_15_181022_colgate naturals_1a.mp4, num_frames: 330, height: 128, width: 128
# filename: alfamen_30_180712_Video como e possivel prevenir.mp4, num_frames: 900, height: 128, width: 128
# filename: v1_180221_Multishow_BBBBumperAd_PaiEFilhaNoBBB.mp4, num_frames: 180, height: 128, width: 128
# filename: alfamen_30_180313_ep_4.mp4, num_frames: 900, height: 128, width: 128
# filename: easynvest_30_180209_bloco dos piratas_05.mp4, num_frames: 451, height: 128, width: 128
# filename: cidadania ja _30_180920_Video resultado do formulario_1b.mp4, num_frames: 900, height: 128, width: 128
# video path: teasers/denise_30_170510_denise dia das maes_02.mp4, exception:
# filename: colgate_30_180423_colgate orthogard_1a.mp4, num_frames: 900, height: 128, width: 128
# filename: alfamen_30_180206_homens com 80 anos.mp4, num_frames: 661, height: 128, width: 128
# filename: alfaman_30_180716_saiba 3 medicamentos_1.mp4, num_frames: 661, height: 128, width: 128
# filename: colgate_30_180427_slim soft advanced.mp4, num_frames: 450, height: 128, width: 128
# filename: alfamen_30_180115_perdendo a forca_3.mp4, num_frames: 900, height: 128, width: 128
# filename: V1_180112_Ilumno - video 2 horizontal_jan_03.mp4, num_frames: 330, height: 128, width: 128
# writing tfrecord: teasers_6.tfrecords
# filename: facebook_15_180626_Campanha Prospect Leads-2018_1c.mp4, num_frames: 330, height: 128, width: 128
# filename: cidadania ja _30_180920_Video pos envio de documentacao_1b.mp4, num_frames: 900, height: 128, width: 128
# video path: teasers/exame_30_170616_exame jun_2.mp4, exception: Smallest dim of frames should be at least greater than 128px
# filename: beer_30_180806_Video Teste clube de assinaturas_1b.mp4, num_frames: 901, height: 128, width: 128
# filename: chocolate brasil cacau_15_180427_cbc alegria.mp4, num_frames: 450, height: 128, width: 128
# filename: cidadania ja _30_181009_Video Institucional_Homepage_2f.mp4, num_frames: 900, height: 128, width: 128
# filename: alfa men_30_180516_perdeu sua forca_02.mp4, num_frames: 661, height: 128, width: 128
# filename: Shoulder_30_181008_Shoulder Experimente o novo_1c.mp4, num_frames: 901, height: 128, width: 128
# filename: antonio bandeiras_30_180328_antonio bandeiras fragrance_05.mp4, num_frames: 451, height: 128, width: 128
# filename: alfamen_30_180411_posso ganhar mais_02.mp4, num_frames: 180, height: 128, width: 128
# filename: alerta app_30_180219_alerta_05.mp4, num_frames: 900, height: 128, width: 128
# filename: carro aluguel_30_180819_conversao carroaluguel_1a.mp4, num_frames: 1800, height: 128, width: 128
# filename: claro_30_170822_claromusica_1.mp4, num_frames: 660, height: 128, width: 128
# filename: facebook_15_180530_Alphaville Urbanismo 45 anos_1c.mp4, num_frames: 450, height: 128, width: 128
# filename: alfamen_30_180313_ep(1).mp4, num_frames: 661, height: 128, width: 128
# filename: v2_050118_bbb_02_pessoasengracadas.mp4, num_frames: 900, height: 128, width: 128
# filename: V1_180122_BBB Apresentacao Brothers_02.mp4, num_frames: 721, height: 128, width: 128
# filename: Aragem Rio_60_180904_Festa de 70 anos Mauro de Oliveira_1c.mp4, num_frames: 902, height: 128, width: 128
# filename: beer_30_180806_Video Teste  - Clube de Assinaturas_1F.mp4, num_frames: 901, height: 128, width: 128
# writing tfrecord: teasers_7.tfrecords
# video path: teasers/adlogados_29_170713_adlogados.mp4, exception:
# filename: colgate_15_171122_golgate90anos_04.mp4, num_frames: 451, height: 128, width: 128
# filename: google_45_181022_automatiza marketing_1a.mp4, num_frames: 1350, height: 128, width: 128
# video path: teasers/finanças femininas_30_180220_teaser cartão_4.mp4, exception: 'ascii' codec can't encode character '\u0327' in position 14: ordinal not in range(128)
# filename: colgate_30_180423_slim soft advanced.mp4, num_frames: 450, height: 128, width: 128
# filename: eventos_15_170412_HC_2.mp4, num_frames: 463, height: 128, width: 128
# filename: eventos_15_170411_grs - santa marta insta.mp4, num_frames: 451, height: 128, width: 128
# filename: alfamen_30_180817_dialogo homem x mulher ep casados.mp4, num_frames: 719, height: 128, width: 128
# filename: Visa_30_180918_Visa l Cross Border l Promocao Mundo Sem Fronteiras_1h.mp4, num_frames: 751, height: 128, width: 128
# filename: crowd mobile_15_170822_ande seguro.mp4, num_frames: 330, height: 128, width: 128
# filename: google unlock_30_180802_campanha demo EADBOX_2a.mp4, num_frames: 660, height: 128, width: 128
# filename: alfamen_30_180313_ep_2.mp4, num_frames: 661, height: 128, width: 128
# filename: alfamen_30_180614_como esta o seu desempenho debaixo dos lencois_1.mp4, num_frames: 661, height: 128, width: 128
# filename: Ilumno Uva Hori Azul_06.mp4, num_frames: 320, height: 128, width: 128
# filename: colgate_30_180424_bolgate pediogard_1a.mp4, num_frames: 900, height: 128, width: 128
# filename: alfamen_30_180111_ansiedade de performance_3.mp4, num_frames: 661, height: 128, width: 128
# filename: facebook_15_180627_Campanha Prospect Leads-2018_1c.mp4, num_frames: 450, height: 128, width: 128
# filename: colgate_30_180427_colgate pediogard_02.mp4, num_frames: 900, height: 128, width: 128
# filename: colgate_30_180507_slim soft advanced_4.mp4, num_frames: 450, height: 128, width: 128
# writing tfrecord: teasers_8.tfrecords
# filename: google_30_180709_Institucional Shpaisman 2018_1g.mp4, num_frames: 661, height: 128, width: 128
# video path: teasers/universidad de palermo_15_180116_estudiá online en la up.mp4, exception: 'ascii' codec can't encode character '\u0301' in position 48: ordinal not in range(128)
# video path: teasers/eventos_15_170412_insta projeto_2.mp4, exception:
# video path: teasers/loreal professionnel_30_180829_vídeo estático solar _1e.mp4, exception: 'ascii' codec can't encode character '\u0301' in position 41: ordinal not in range(128)
# filename: colgate_30_180426_colgate orthogard_02.mp4, num_frames: 900, height: 128, width: 128
# filename: alfa men_30_181019_gostaria de aumentar seus momentos de prazer.mp4, num_frames: 900, height: 128, width: 128
# filename: alfaman_30_180613_ quanto tempo dura o seu jogo debaixo dos lencois_1.mp4, num_frames: 661, height: 128, width: 128
# video path: teasers/eventos_15_170412_warehouse_1.mp4, exception:
# filename: bit.one_30_180529_Video 01 - Passo a passo _1e.mp4, num_frames: 900, height: 128, width: 128
# filename: beer_30_180808_video teste clube de assinaturas_1f.mp4, num_frames: 901, height: 128, width: 128
# filename: google unlock_30_180809_cr trueview_3.mp4, num_frames: 661, height: 128, width: 128
# filename: crowd mobile_15_170825_ande seguro_4.mp4, num_frames: 661, height: 128, width: 128
# filename: facebook_15_180614_araujo_1d.mp4, num_frames: 450, height: 128, width: 128
# filename: plataforma 10_30_180619_vacaciones de invierno_1b.mp4, num_frames: 900, height: 128, width: 128
# filename: Visa_30_180919_Visa l Cross Border l Promocao Mundo Sem Fronteiras_1M.mp4, num_frames: 751, height: 128, width: 128
# filename: v1_180216_Multishow_BBBMelhoresMomentos_PegadinhaDoRato.mp4, num_frames: 900, height: 128, width: 128
# filename: bornlogic_15_180126_ilumnouva vertical azul_04.mp4, num_frames: 320, height: 128, width: 128
# filename: bitone_30_180810_video vantagens lojista_2.mp4, num_frames: 661, height: 128, width: 128
# filename: beer_30_180807_Video Teste  - Clube de Assinaturas_1G.mp4, num_frames: 901, height: 128, width: 128
# writing tfrecord: teasers_9.tfrecords
# filename: Visa_30_180919_Visa l Cross Border l Promocao Mundo Sem Fronteiras_1i.mp4, num_frames: 751, height: 128, width: 128
# filename: beer_30_180801_Video Teste  - Clube de Assinaturas_vertical_1d.mp4, num_frames: 901, height: 128, width: 128
# filename: alfa men_30_180927_de onde vem nossos pacientes minas_1b.mp4, num_frames: 900, height: 128, width: 128
# filename: bit.one_30_180518_video 01 - passo a passo _1.mp4, num_frames: 900, height: 128, width: 128
# filename: beer_30_180817_eisenbahn_1c.mp4, num_frames: 450, height: 128, width: 128
# filename: claro_30_170904_claromusica_1a.mp4, num_frames: 660, height: 128, width: 128
# filename: colgate_30_180402_Institucional lr_02.mp4, num_frames: 450, height: 128, width: 128
# filename: alfa men_30_181002_de onde vem nossos pacientes sp_1b.mp4, num_frames: 900, height: 128, width: 128
# video path: teasers/universidad de palermo_6_180116_online o presencialvos elegís - jan_03.mp4, exception: 'ascii' codec can't encode character '\u0301' in position 68: ordinal not in range(128)
# filename: Visa_30_180918_Visa l Cross Border l Promocao Mundo Sem Fronteiras_1f.mp4, num_frames: 751, height: 128, width: 128
# video path: teasers/flamengo_30_180317_roteiro off rio_8.mp4, exception:
# filename: easynvest_30_180221_aquecimento para investir bem em 2018_fev.mp4, num_frames: 661, height: 128, width: 128
# filename: cidadania ja _30_181009_Video para Instagram - Cidadania Ja_1b.mp4, num_frames: 900, height: 128, width: 128
# filename: easynvest_30_180215_trio do sobe e desce.mp4, num_frames: 360, height: 128, width: 128
# filename: b ferraz_30_171220_compartilhar vertical.mp4, num_frames: 451, height: 128, width: 128
# filename: alfamen_30_180313_desempenho_4.mp4, num_frames: 900, height: 128, width: 128
# filename: beer_30_180807_Video Teste  - Clube de Assinaturas_1H.mp4, num_frames: 901, height: 128, width: 128
# video path: teasers/denise_30_170608_namorados.mp4, exception:
# filename: bitone_30_180808_video vantagens lojista_1a.mp4, num_frames: 661, height: 128, width: 128
# writing tfrecord: teasers_10.tfrecords
# filename: colgate_30_180419_colgate total 12 saude visivel_03.mp4, num_frames: 450, height: 128, width: 128
# video path: teasers/universidad de palermo_15_180528_estudiá, creá. viví negocios_1b.mp4, exception: 'ascii' codec can't encode character '\u0301' in position 48: ordinal not in range(128)
# filename: facebook_15_180525_Tegra SP - Institucional v1_1b.mp4, num_frames: 450, height: 128, width: 128
# filename: alfamen_30_180123_43_2b.mp4, num_frames: 901, height: 128, width: 128
# filename: Ilumno Uva Vert Verde_06.mp4, num_frames: 320, height: 128, width: 128
# filename: PILULAS BBB P MKT.mp4, num_frames: 5472, height: 128, width: 128
# filename: carro aluguel_30_181001_e seguro alugar_1b.mp4, num_frames: 900, height: 128, width: 128
# video path: teasers/flexipag_30_180320_detalhe dos benefícios_4.mp4, exception: 'ascii' codec can't encode character '\u0301' in position 45: ordinal not in range(128)
# filename: conquista_15_180502_conquista jardim amaralina segunda fase_3b.mp4, num_frames: 330, height: 128, width: 128
# filename: biz capital_30_180420_youtube_06(1).mp4, num_frames: 450, height: 128, width: 128
# video path: teasers/flapper_30_180219_os aviões mais seguros do brasil_07.mp4, exception: 'ascii' codec can't encode character '\u0303' in position 33: ordinal not in range(128)
# filename: alfamen_30_180115_ansiedade de performance_2.mp4, num_frames: 837, height: 128, width: 128
# filename: colgate_30_171114_golgate90anos_03a.mp4, num_frames: 451, height: 128, width: 128
# filename: conquista_15_180122_conquista amaralina_2.mp4, num_frames: 331, height: 128, width: 128
# filename: alfa men_30_180927_de onde vem nossos pacientes sp.mp4, num_frames: 900, height: 128, width: 128
# filename: alfamen_30_180313_ep.mp4, num_frames: 661, height: 128, width: 128
# filename: colgate_15_1800831_Emex nossa historia_1f.mp4, num_frames: 450, height: 128, width: 128
# filename: colgate_30_181024_colgate naturals_2.mp4, num_frames: 661, height: 128, width: 128
# filename: beer_30_180817_eisenbahn_1d.mp4, num_frames: 450, height: 128, width: 128
# writing tfrecord: teasers_11.tfrecords
# filename: v2_180215_Multishow_BBBMelhoresMomentos_PaiEFilhaNoBBB_CLARO_01.mp4, num_frames: 900, height: 128, width: 128
# filename: conquista_15_180116_conquista amaralina.mp4, num_frames: 331, height: 128, width: 128
# filename: colgate_30_180424_colgate orthogard.mp4, num_frames: 900, height: 128, width: 128
# filename: bitone_30_180824_video vantagens lojista_1_vertical_curto.mp4, num_frames: 900, height: 128, width: 128
# filename: arcor_30_180731_Big Big Campanha_1b.mp4, num_frames: 661, height: 128, width: 128
# filename: facebook_30_181010_creative for whatsapp_1a.mp4, num_frames: 900, height: 128, width: 128
# filename: cidadania ja _30_181016_video de inauguracao da loja niteroi_1a.mp4, num_frames: 360, height: 128, width: 128
# filename: central de pasajes_30_180322_central de pasajes_02.mp4, num_frames: 900, height: 128, width: 128
# filename: a tarde_116_170905_institucional_4.mp4, num_frames: 3502, height: 128, width: 128
# filename: google_leadaki_30_181019_emblue_2.mp4, num_frames: 661, height: 128, width: 128
# filename: deezer_30_180521_video tim music - consumer online_1.mp4, num_frames: 900, height: 128, width: 128
# filename: alfamen_30_180411_hipertensao x disfuncao eretil.mp4, num_frames: 661, height: 128, width: 128
# filename: easy carros_30_171127_easycarros_03.mp4, num_frames: 900, height: 128, width: 128
# filename: alfamen_30_180313_ep_3.mp4, num_frames: 900, height: 128, width: 128
# filename: digible_30_171206_digible audio.mp4, num_frames: 749, height: 128, width: 128
# filename: alfamen_30_180823_dialogo homem x mulher de casados_3b.mp4, num_frames: 660, height: 128, width: 128
# filename: Visa_30_180918_Visa l Cross Border l Promocao Mundo Sem Fronteiras_1e.mp4, num_frames: 800, height: 128, width: 128
# filename: alfamen_30_180123_43_2.mp4, num_frames: 901, height: 128, width: 128
# filename: crowd mobile_15_170823_ande seguro_2.mp4, num_frames: 330, height: 128, width: 128
# writing tfrecord: teasers_12.tfrecords
# filename: colgate_30_171113_golgate90anos_02.mp4, num_frames: 450, height: 128, width: 128
# filename: conquista_15_180125_conquista amaralina_5.mp4, num_frames: 331, height: 128, width: 128
# video path: teasers/finaças femininas_30_180219_teaser cartão_02.mp4, exception: 'ascii' codec can't encode character '\u0327' in position 13: ordinal not in range(128)
# filename: crowd mobile_15_170825_ande seguro_3.mp4, num_frames: 661, height: 128, width: 128
# filename: alfa men_30_180517_o que 90_ dos homens_01.mp4, num_frames: 900, height: 128, width: 128
# filename: easynvest_30_180223_aquecimento para investir bem em 2018_02.mp4, num_frames: 661, height: 128, width: 128
# filename: alfa men_30_180515_qual a sua velocidade_02.mp4, num_frames: 662, height: 128, width: 128
# filename: Visa_15_180919_Visa l Cross Border l Promocao Mundo Sem Fronteiras_15seg_HORIZONTAL_2d.mp4, num_frames: 376, height: 128, width: 128
# video path: teasers/norte digital_30_180912_Verdhia Cajicá.mp4, exception: 'ascii' codec can't encode character '\u0301' in position 46: ordinal not in range(128)
# video path: teasers/flapper_30_180510_segurança.mp4, exception: 'ascii' codec can't encode character '\u0327' in position 34: ordinal not in range(128)
# filename: colgate_30_180507_slim soft advanced_3.mp4, num_frames: 450, height: 128, width: 128
# video path: teasers/flamengo_30_170307_libertadores_2b.mp4, exception:
# filename: eventos_15_170411_reveillon gavea_2.mp4, num_frames: 476, height: 128, width: 128
# filename: bitone_30_180824_video vantagens lojista_1_Vertical.mp4, num_frames: 900, height: 128, width: 128
# video path: teasers/denise macedo_30_170410_pascoa_02.mp4, exception:
# filename: flapper_30_180305_pilatus_2b.mp4, num_frames: 661, height: 128, width: 128
# video path: teasers/google latam_30_180215_campaña branding - providence viajes_02.mp4, exception: 'ascii' codec can't encode character '\u0303' in position 37: ordinal not in range(128)
# filename: bornlogic_15_180126_ilumnouva vertical azul_04a.mp4, num_frames: 320, height: 128, width: 128
# filename: V1_180109_Ilumno (UVA)_jan.mp4, num_frames: 330, height: 128, width: 128
# writing tfrecord: teasers_13.tfrecords
# filename: facebook_15_180525_Alphaville Urbanismo 45 anos.mp4, num_frames: 450, height: 128, width: 128
# filename: V1_180122_BBB Apresentacao Brothers_03.mp4, num_frames: 714, height: 128, width: 128
# filename: colgate_15_1800813_Emex nossa historia_1c.mp4, num_frames: 450, height: 128, width: 128
# filename: cidadania ja _30_181004_Video para Instagram - Cidadania Ja_1b.mp4, num_frames: 900, height: 128, width: 128
# filename: v1_180209_Multishow_BBBMelhoresMomentos_SentaAquiSeuFalso_NET_01.mp4, num_frames: 900, height: 128, width: 128
# filename: Visa_30_180914_Visa l Cross Border l Promocao Mundo Sem Fronteiras.mp4, num_frames: 751, height: 128, width: 128
# filename: universidad de palermo_15_180903_comunidad global_1b.mp4, num_frames: 450, height: 128, width: 128
# filename: eco challenge_30_171101_eco desafios_03.mp4, num_frames: 661, height: 128, width: 128
# filename: colgate_30_180427_colgate orthogard_03.mp4, num_frames: 900, height: 128, width: 128
# filename: b ferraz_30_171219_compartilhar vertical_02.mp4, num_frames: 451, height: 128, width: 128
# filename: go dog_30_180307_go dog no we work_2.mp4, num_frames: 661, height: 128, width: 128
# filename: colgate_30_180405_institucional lr_03.mp4, num_frames: 450, height: 128, width: 128
# filename: Visa_30_180914_Visa l Cross Border l Promocao Mundo Sem Fronteiras 1b.mp4, num_frames: 751, height: 128, width: 128
# filename: norte digital_30_180912_Verdhia tenjo.mp4, num_frames: 751, height: 128, width: 128
# filename: facebook_15_180626_Campanha Prospect Leads-2018_1a.mp4, num_frames: 330, height: 128, width: 128
# filename: eventos_15_170412_porn_3.mp4, num_frames: 450, height: 128, width: 128
# filename: colgate_15_181019_Video Institucional - Eventos Esportivos.mp4, num_frames: 452, height: 128, width: 128
# filename: beer_30_180801_Video Teste  - Clube de Assinaturas_1c.mp4, num_frames: 901, height: 128, width: 128
# filename: conquista_15_180503_conquista jardim amaralina segunda fase_4b.mp4, num_frames: 330, height: 128, width: 128
# writing tfrecord: teasers_14.tfrecords
# video path: teasers/google unlock_30_180809_tagg one_chaves na mão_1.mp4, exception: 'ascii' codec can't encode character '\u0303' in position 53: ordinal not in range(128)
# filename: Aragem Rio_60_180904_Festa de 70 anos Mauro de Oliveira_1e.mp4, num_frames: 902, height: 128, width: 128
# filename: universidad de palermo_15_180828_ingenieria.mp4, num_frames: 330, height: 128, width: 128
# filename: claro_30_170822_claromusica_2.mp4, num_frames: 660, height: 128, width: 128
# filename: colgate_15_1800813_Emex nossa historia_1d.mp4, num_frames: 450, height: 128, width: 128
# filename: alfamen_30_180822_dialogo homem x mulher ep_2.mp4, num_frames: 719, height: 128, width: 128
# filename: antonio bandeiras_30_180327_antonio bandeiras fragrance_02.mp4, num_frames: 451, height: 128, width: 128
# filename: beer_30_180808_video teste  - clube de Assinaturas_1i.mp4, num_frames: 901, height: 128, width: 128
# filename: Visa_30_180919_Visa l Cross Border l Promocao Mundo Sem Fronteiras_1j.mp4, num_frames: 751, height: 128, width: 128
# filename: Ilumno Uva Hori Verde_06.mp4, num_frames: 320, height: 128, width: 128
# filename: bornlogic_15_180126_ilumnouva horizontal verde_04a.mp4, num_frames: 320, height: 128, width: 128
# filename: facebook_30_181017_messengerA_1a.mp4, num_frames: 375, height: 128, width: 128
# filename: facebook_30_181017_Creative for Whatsapp_Espanhol_1b.mp4, num_frames: 900, height: 128, width: 128
# filename: Visa_15_180919_Visa l Cross Border l Promocao Mundo Sem Fronteiras_15seg_VERTICAL_2c.mp4, num_frames: 376, height: 128, width: 128
# filename: alfamen_30_180614_Video Alfa Men O que fazer quando ele nao quer funcionar_1.mp4, num_frames: 662, height: 128, width: 128
# video path: teasers/exame_30_160622_app_2b.mp4, exception: Smallest dim of frames should be at least greater than 128px
# video path: teasers/eventos_15_170412_mardigras insta_2.mp4, exception:
# filename: facebook_30_181017_Creative for Whatsapp_PT.mp4, num_frames: 900, height: 128, width: 128
# filename: loreal professionnel_10_181029_serie expert_BLONDIFIER_1a.mp4, num_frames: 451, height: 128, width: 128
# writing tfrecord: teasers_15.tfrecords
# filename: unipar_30_180615_video institucional unipar_1c.mp4, num_frames: 662, height: 128, width: 128
# filename: colgate_30_171114_golgate90anos_03b.mp4, num_frames: 900, height: 128, width: 128
# filename: Visa_15_180919_Visa l Cross Border l Promocao Mundo Sem Fronteiras_15seg_HORIZONTAL.mp4, num_frames: 376, height: 128, width: 128
# video path: teasers/eventos_15_170412_cade tereza insta.mp4, exception:
# filename: colgate_30_180427_slim soft advanced_02.mp4, num_frames: 450, height: 128, width: 128
# filename: arcor_30_180731_Big Big Campanha_1c.mp4, num_frames: 661, height: 128, width: 128
# filename: adlogados_30_170608_adlogados_2.mp4, num_frames: 900, height: 128, width: 128
# video path: teasers/eventos_15_170412_tropkillaz white rooftop_2.mp4, exception:
# video path: teasers/eventos_15_170411_mar insta.mp4, exception:
# filename: plataforma 10_30_180618_vacaciones de invierno_1a.mp4, num_frames: 900, height: 128, width: 128
# filename: alfamen_30_180928_que notas elas dariam pro seu desempenho.mp4, num_frames: 900, height: 128, width: 128
# filename: v2_080118_bbb_03_pessoasengracadas.mp4, num_frames: 900, height: 128, width: 128
# filename: BBB Melhores Momentos - Inocencia Kaysar 03.mp4, num_frames: 900, height: 128, width: 128
# filename: colgate_30_171122_golgate90anos_04b.mp4, num_frames: 900, height: 128, width: 128
# filename: eco challenge_30_171101_eco desafios_05.mp4, num_frames: 661, height: 128, width: 128
# filename: coverdox_30_181019_medicos agredidos ou ameacados_2.mp4, num_frames: 661, height: 128, width: 128
# filename: colgate_30_180411_colgate total 12 saude visivel_01.mp4, num_frames: 450, height: 128, width: 128
# filename: adlogados_30_170315_adlogados.mp4, num_frames: 900, height: 128, width: 128
# filename: alfamen_30_180612_Video Coverdox Seguro de renda protegida1b.mp4, num_frames: 661, height: 128, width: 128
# writing tfrecord: teasers_16.tfrecords
# video path: teasers/curseria_15_180511_campanha stories fogaça 01_01.mp4, exception: 'ascii' codec can't encode character '\u0327' in position 49: ordinal not in range(128)
# filename: V1_180111_Video 40 Alfa Men Ansiedade de performance_jan.mp4, num_frames: 661, height: 128, width: 128
# filename:  singu_15_180829_singu - campanha youtube_3a.mp4, num_frames: 450, height: 128, width: 128
# filename: deezer_30_180427_video tim music_3.mp4, num_frames: 900, height: 128, width: 128
# filename: alfamen_30_180220_coverdox_02.mp4, num_frames: 900, height: 128, width: 128
# filename: Ilumno Uva Hori Azul_05.mp4, num_frames: 320, height: 128, width: 128
# filename: V1_180112_Ilumno - video 2 horizontal_jan_02.mp4, num_frames: 330, height: 128, width: 128
# filename: beer_30_180920_eisenbahn_1f.mp4, num_frames: 450, height: 128, width: 128
# filename: b ferraz_30_171219_compartilhar.mp4, num_frames: 451, height: 128, width: 128
# video path: teasers/facebook_15_180622_Unboxing Clube Jorge _ Mateus_1b.mp4, exception:
# filename: facebook_15_180525_Tegra SP - Institucional v1_1.mp4, num_frames: 450, height: 128, width: 128
# filename: easynvest_30_180213_trio do sobe e desce.mp4, num_frames: 360, height: 128, width: 128
# filename: arcor_30_180731_Big Big Campanha_1e.mp4, num_frames: 661, height: 128, width: 128
# filename: eco challenge_30_171027_eco desafios_01.mp4, num_frames: 720, height: 128, width: 128
# filename: facebook_30_181016_Creative for Whatsapp_1c.mp4, num_frames: 900, height: 128, width: 128
# filename: digible_30_171206_digible audio_2.mp4, num_frames: 749, height: 128, width: 128
# filename: alfa men_30_180518_perdeu sua forca_03.mp4, num_frames: 901, height: 128, width: 128
# filename: b ferraz_30_171220_compartilhar vertical_02.mp4, num_frames: 451, height: 128, width: 128
# filename: conquista_15_180426_conquista jardim amaralina segunda Fase 2.mp4, num_frames: 330, height: 128, width: 128
# writing tfrecord: teasers_17.tfrecords
# filename: digible_30_171211_digible audio_5.mp4, num_frames: 749, height: 128, width: 128
# filename: antonio bandeiras_30_180327_antonio bandeiras fragrance_03.mp4, num_frames: 451, height: 128, width: 128
# filename: digible_30_171208_digible audio_4.mp4, num_frames: 749, height: 128, width: 128
# filename: deezer_30_180521_video tim music - consumer online_1b.mp4, num_frames: 900, height: 128, width: 128
# filename: Google Unlock_30_180711_ Salete Flores_2a.mp4, num_frames: 900, height: 128, width: 128
# filename: alfa men_30_180927_de onde vem nossos pacientes minas.mp4, num_frames: 900, height: 128, width: 128
# filename: facebook_15_180529_RMA Comunicacao_Campanha PR SCOPE_1.mp4, num_frames: 450, height: 128, width: 128
# filename: alfamen_30_180817_dialogo homem x mulher de casados.mp4, num_frames: 719, height: 128, width: 128
# filename: colgate_30_180416_colgate total 12 saude visivel_02.mp4, num_frames: 450, height: 128, width: 128
# filename: alfamen_30_180206_44.mp4, num_frames: 660, height: 128, width: 128
# filename: easynvest_30_180223_aquecimento para investir bem em 2018_03.mp4, num_frames: 661, height: 128, width: 128
# filename: arcor_30_180810_Big Big Campanha_1f.mp4, num_frames: 900, height: 128, width: 128
# filename: facebook_15_180621_horizon alto da lapa_1b.mp4, num_frames: 330, height: 128, width: 128
# video path: teasers/pack asap_30_180518_campaña branding packasap_2.mp4, exception: 'ascii' codec can't encode character '\u0303' in position 34: ordinal not in range(128)
# filename: Visa_15_180919_Visa l Cross Border l Promocao Mundo Sem Fronteiras_15seg_HORIZONTAL_2b.mp4, num_frames: 376, height: 128, width: 128
# filename: facebook_15_180614_araujo_1c.mp4, num_frames: 450, height: 128, width: 128
# filename: v1_180209_Multishow_BBBMelhoresMomentos_SentaAquiSeuFalso_CLARO_01.mp4, num_frames: 900, height: 128, width: 128
# filename: beer_30_180801_Video Teste  - Clube de Assinaturas_vertical_1e.mp4, num_frames: 901, height: 128, width: 128
# filename: adlogados_30_170713_adlogados.mp4, num_frames: 660, height: 128, width: 128
# writing tfrecord: teasers_18.tfrecords
# filename: alfaman_30_180620_ quanto tempo dura o seu jogo debaixo dos lencois_2.mp4, num_frames: 661, height: 128, width: 128
# filename: alfamen_30_180219_48_2.mp4, num_frames: 661, height: 128, width: 128
# filename: google latam_30_181217_efectivoahora - como solicitar.mp4, num_frames: 900, height: 128, width: 128
# filename: conquist_15_180503_conquista jardim amaralina segunda fase_4.mp4, num_frames: 330, height: 128, width: 128
# filename: alfamen_30_180928_Video Alfa Men - Existe cirurgia pra tratar ejaculacao precoce_1a.mp4, num_frames: 900, height: 128, width: 128
# filename: alfamen_30_180315_voce gostaria de aumentar os seus momentos.mp4, num_frames: 661, height: 128, width: 128
# filename: facebook_30_181023_Creative for Whatsapp_english_1b.mp4, num_frames: 900, height: 128, width: 128
# filename: bitone_30_180807_video vantagens lojista_1.mp4, num_frames: 661, height: 128, width: 128
# filename: alfa men_30_180518_o que 90_ dos homens_02.mp4, num_frames: 900, height: 128, width: 128
# filename: v1_180216_Multishow_BBBMelhoresMomentos_BrigaTodoDia_BundaMole.mp4, num_frames: 900, height: 128, width: 128
# filename: google unlock_30_180809_yt sage business cloud_3a.mp4, num_frames: 662, height: 128, width: 128
# filename: antonio bandeiras_30_180327_antonio bandeiras fragrance_01.mp4, num_frames: 451, height: 128, width: 128
# filename: norte digital_30_180906_campana allianz world run_1d.mp4, num_frames: 900, height: 128, width: 128
# filename: claro_30_170919_claromusica_2b.mp4, num_frames: 660, height: 128, width: 128
# filename: conquista_15_180426_conquista jardim amaralina segunda fase_2.mp4, num_frames: 330, height: 128, width: 128
# filename: v1_180209_Multishow_BBBMelhoresMomentos_PaiEFilhaNoBBB_CLARO_01.mp4, num_frames: 900, height: 128, width: 128
# filename: alphamen_30_180615_Video alfamen O que 90_ dos homens_03.mp4, num_frames: 900, height: 128, width: 128
# filename: biz capital_30_180424_youtube_08.mp4, num_frames: 450, height: 128, width: 128
# filename: facebook_30_181022_Creative for Whatsapp_Espanhol_1b.mp4, num_frames: 900, height: 128, width: 128
# writing tfrecord: teasers_19.tfrecords
# filename: carro aluguel_30_180814_video campanha institucional_1c.mp4, num_frames: 901, height: 128, width: 128
# filename: carro aluguel_30_180814_video campanha institucional_1b.mp4, num_frames: 901, height: 128, width: 128
# filename: carro aluguel_30_180928_o que e calcao_1c.mp4, num_frames: 901, height: 128, width: 128
# filename: biz capital_30_180328_youtube_01.mp4, num_frames: 451, height: 128, width: 128
# filename: alerta app_30_180208_alerta_04.mp4, num_frames: 900, height: 128, width: 128
# video path: teasers/eventos_15_170412_ja rule_2.mp4, exception: Smallest dim of frames should be at least greater than 128px
# filename: Ilumno Uva Vert Azul_03.mp4, num_frames: 330, height: 128, width: 128
# filename: cidadania ja _30_180920_Video Institucional_Home _1a.mp4, num_frames: 900, height: 128, width: 128
# filename: alfamen_30_180419_pode nao ter mais tratamento_2.mp4, num_frames: 661, height: 128, width: 128
# filename: norte digital central de pasajes_30_180815_soy estudiante_1f.mp4, num_frames: 720, height: 128, width: 128
# filename: alfamen_30_180118_43.mp4, num_frames: 901, height: 128, width: 128
# filename: eco challenge_30_171101_eco desafios_04.mp4, num_frames: 661, height: 128, width: 128
# filename: cidadania ja _30_180920_Video pos envio de documentacao_1a.mp4, num_frames: 900, height: 128, width: 128
# filename: adlogados_30_180731_escritorio supremo_1c.mp4, num_frames: 660, height: 128, width: 128
# filename: bornlogic_15_180126_ilumnouva vertical verde_04.mp4, num_frames: 320, height: 128, width: 128
# filename: cidadania ja _30_180928_Video pos envio de documentacao_2b.mp4, num_frames: 900, height: 128, width: 128
# filename: dafiti_15_180906_Verao, pode chegar_1a.mp4, num_frames: 376, height: 128, width: 128
# filename: antonio bandeiras_30_180328_antonio bandeiras fragrance_04.mp4, num_frames: 451, height: 128, width: 128
# video path: teasers/adlogados_30_170504_adlogados_2.mp4, exception:
# writing tfrecord: teasers_20.tfrecords
# filename: alfamen_30_180816_dialogo homem x mulher de.mp4, num_frames: 719, height: 128, width: 128
# filename: alfamen_30_180822_dialogo homem x mulher ep casados_2.mp4, num_frames: 719, height: 128, width: 128
# filename: facebook_15_180601_Tegra SP - Institucional v1_1c.mp4, num_frames: 450, height: 128, width: 128
# filename: colgate_30_180424_colgate pediogard_1b.mp4, num_frames: 900, height: 128, width: 128
# filename: biz capital_30_180404_youtube_03.mp4, num_frames: 450, height: 128, width: 128
# filename: bit.one_30_180523_Video 01 - Passo a passo _1c.mp4, num_frames: 900, height: 128, width: 128
# filename: facebook_30_180419_facebook x instagram_03.mp4, num_frames: 900, height: 128, width: 128
# filename: V1_180121_BBB Apresentacao Brothers_02.mp4, num_frames: 721, height: 128, width: 128
# filename: easynvest_30_180207_bloco dos piratas_03.mp4, num_frames: 330, height: 128, width: 128
# filename: Leadaki__30_180911_ F5 Centro de Estudios_1b.mp4, num_frames: 901, height: 128, width: 128
# filename: carro aluguel_30_180814_video campanha institucional_1a.mp4, num_frames: 901, height: 128, width: 128
# filename: alfa men_30_180417_mulheres tem dificuldade de alcancar o prazer.mp4, num_frames: 900, height: 128, width: 128
# filename: conquista_15_180419_conquista jardim amaralina segunda fase_02.mp4, num_frames: 330, height: 128, width: 128
# video path: teasers/BBB Melhores Momentos - Primeiro Lider_02.mp4, exception:
# filename: facebook_15_180622_Unboxing Clube Jorge _ Mateus_1c.mp4, num_frames: 330, height: 128, width: 128
# filename: alfamen_30_180220_46_02.mp4, num_frames: 900, height: 128, width: 128
# filename: V1_180112_Ilumno - video 2 horizontal_jan.mp4, num_frames: 330, height: 128, width: 128
# filename: colgate_15_1800809_Emex nossa historia_1b.mp4, num_frames: 450, height: 128, width: 128
# filename: adlogados_30_180730_escritorio supremo_1b.mp4, num_frames: 660, height: 128, width: 128
# writing tfrecord: teasers_21.tfrecords
# filename: dafiti_15_180917_Verao, pode chegar_1b.mp4, num_frames: 361, height: 128, width: 128
# filename: V1_180122_BBB Apresentacao Brothers_05.mp4, num_frames: 713, height: 128, width: 128
# filename: universidad de palermo_30_180604_universidad de palermo_1d.mp4, num_frames: 451, height: 128, width: 128
# filename: alfa men_30_180927_de onde vem nossos pacientes poa_1b.mp4, num_frames: 900, height: 128, width: 128
# filename: eventos_15_170412_beach house_2.mp4, num_frames: 453, height: 128, width: 128
# filename: colgate_30_181024_colgate naturals_3.mp4, num_frames: 661, height: 128, width: 128
# filename: alfamen_30_180220_46.mp4, num_frames: 900, height: 128, width: 128
# filename: bossanovamall_15_180220_video institucional 3_2.mp4, num_frames: 330, height: 128, width: 128
# filename: facebook_30_180419_facebook x instagram_03b.mp4, num_frames: 900, height: 128, width: 128
# filename: conquista_15_180705_conquista j amaralina - vertical_1b.mp4, num_frames: 330, height: 128, width: 128
# filename: Visa_15_180919_Visa l Cross Border l Promocao Mundo Sem Fronteiras_15seg_HORIZONTAL_2c.mp4, num_frames: 376, height: 128, width: 128
